# %%
from motmot.SpiderMovie import SpiderMovie
fname='Z:\HsinYi\Test Video From Darya/test clip/raw/bias_video_cam_2_date_2023_05_31_time_19_56_23_v001.24.fmf'
mov = SpiderMovie(fname)
import numpy as np
data = np.load('Z:\HsinYi\Test Video From Darya/test clip\croprot/bias_video_cam_2_date_2023_05_31_time_19_56_23_v001.all.s_dlc_abs.npy')
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
plt.imshow(mov[0])
plt.scatter(data[0,:,0], data[0,:,1], s=1, c='r')
plt.show()
